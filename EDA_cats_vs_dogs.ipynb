# %%
import os
from matplotlib import pyplot
from matplotlib.image import imread

# %%
# Define the directory to be inspected as a list
list_train = os.listdir("train")

# Obtain total number of images
number_files_train = len(list_train)
print("Number of images: " + str(number_files_train))

number_cats_train = 0
number_dogs_train = 0

# Iterate directory and print and count images of each class
for image in list_train:
    
    if image[:3] == 'cat':
        
        number_cats_train = number_cats_train + 1
        
    else:
        
        number_dogs_train = number_dogs_train + 1   
        
    print(image)     
    
    
print("Number of cat images: " + str(number_cats_train))
print("Number of dog images: " + str(number_dogs_train))
# Out:
# 25000
# cat.0.jpg
# cat.1.jpg
# cat.10.jpg
# cat.100.jpg
# cat.1000.jpg
# cat.10000.jpg
# cat.10001.jpg
# cat.10002.jpg
# cat.10003.jpg
# cat.10004.jpg
# cat.10005.jpg
# cat.10006.jpg
# cat.10007.jpg
# cat.10008.jpg
# cat.10009.jpg
# cat.1001.jpg
# cat.10010.jpg
# cat.10011.jpg
# cat.10012.jpg
# cat.10013.jpg
# cat.10014.jpg
# cat.10015.jpg
# cat.10016.jpg
# cat.10017.jpg
# cat.10018.jpg
# cat.10019.jpg
# cat.1002.jpg
# cat.10020.jpg
# cat.10021.jpg
# cat.10022.jpg
# cat.10023.jpg
# cat.10024.jpg
# cat.10025.jpg
# cat.10026.jpg
# cat.10027.jpg
# cat.10028.jpg
# cat.10029.jpg
# cat.1003.jpg
# cat.10030.jpg
# cat.10031.jpg
# cat.10032.jpg
# cat.10033.jpg
# cat.10034.jpg
# cat.10035.jpg
# cat.10036.jpg
# cat.10037.jpg
# cat.10038.jpg
# cat.10039.jpg
# cat.1004.jpg
# cat.10040.jpg
# cat.10041.jpg
# cat.10042.jpg
# cat.10043.jpg
# cat.10044.jpg
# cat.10045.jpg
# cat.10046.jpg
# cat.10047.jpg
# cat.10048.jpg
# cat.10049.jpg
# cat.1005.jpg
# cat.10050.jpg
# cat.10051.jpg
# cat.10052.jpg
# ...

# %%
# Define the directory to be inspected as a list
list_test = os.listdir("test1")

#Obtain total number of images
number_files_test = len(list_test)
print("Number of images: " + str(number_files_test))

# Iterate directory 
for image in list_test:   
        
    print(image)
# Out:
# Number of images: 12500
# 1.jpg
# 10.jpg
# 100.jpg
# 1000.jpg
# 10000.jpg
# 10001.jpg
# 10002.jpg
# 10003.jpg
# 10004.jpg
# 10005.jpg
# 10006.jpg
# 10007.jpg
# 10008.jpg
# 10009.jpg
# 1001.jpg
# 10010.jpg
# 10011.jpg
# 10012.jpg
# 10013.jpg
# 10014.jpg
# 10015.jpg
# 10016.jpg
# 10017.jpg
# 10018.jpg
# 10019.jpg
# 1002.jpg
# 10020.jpg
# 10021.jpg
# 10022.jpg
# 10023.jpg
# 10024.jpg
# 10025.jpg
# 10026.jpg
# 10027.jpg
# 10028.jpg
# 10029.jpg
# 1003.jpg
# 10030.jpg
# 10031.jpg
# 10032.jpg
# 10033.jpg
# 10034.jpg
# 10035.jpg
# 10036.jpg
# 10037.jpg
# 10038.jpg
# 10039.jpg
# 1004.jpg
# 10040.jpg
# 10041.jpg
# 10042.jpg
# 10043.jpg
# 10044.jpg
# 10045.jpg
# 10046.jpg
# 10047.jpg
# 10048.jpg
# 10049.jpg
# 1005.jpg
# 10050.jpg
# 10051.jpg
# 10052.jpg
# 10053.jpg
# 10054.jpg
# 10055.jpg
# 10056.jpg
# 10057.jpg
# 10058.jpg
# 10059.jpg
# 1006.jpg
# 10060.jpg
# 10061.jpg
# 10062.jpg
# 10063.jpg
# 10064.jpg
# 10065.jpg
# 10066.jpg
# 10067.jpg
# 10068.jpg
# 10069.jpg
# 1007.jpg
# 10070.jpg
# ...

# %%
# Plot dog photos from the dogs vs cats dataset

# Define location of dataset
folder = 'train/'

# Plot first few images
for i in range(9):
    # Define subplot
    pyplot.subplot(330 + 1 + i)
    # Define filename
    filename = folder + 'dog.' + str(i) + '.jpg'
    # Load image pixels
    image = imread(filename)
    # Plot raw pixel data
    pyplot.imshow(image)
    
# Show the figure
pyplot.show()

# %%
# Plot cat photos from the dogs vs cats dataset

# Define location of dataset
folder = 'train/'
# Plot first few images
for i in range(9):
    # Define subplot
    pyplot.subplot(330 + 1 + i)
    # Define filename
    filename = folder + 'cat.' + str(i) + '.jpg'
    # Load image pixels
    image = imread(filename)
    # Plot raw pixel data
    pyplot.imshow(image)
# Show the figure
pyplot.show()
